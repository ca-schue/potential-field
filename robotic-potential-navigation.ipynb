# %% [markdown]
# # 1) Choose or modify one scenario

# %% [markdown]
# ### "Good Case" for attractive & repulsive potential

# %%
# 1x2 Robot, 45° Rotation, 18x18 Occu. Grid, 1 Obstacle in middle (Demonstrats attractive and repulsive potential)

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Robotermaße
robot_width = 1
robot_length = 2

# Rotationsgranularität (Grad)
rotation_step = 45

# Start- und Zielpunkt festlegen (X,Y,Rotation) - Ausrichtung Roboter in Grad = Rotation * rotation_step
start_point = (2, 13, 0)
goal_point = (13, 3, 0)
current_position=start_point

# Potenzialfunktion
wavefront_potential_function = False
attraction_repulsion_potential_function = True
attraction_weight= 2
repulsion_weight= 0

# Plots
optional_plots = True # Set true only for width/height <= 30px and rotation_step >= 30° (Very resource intensive)
gradient_decent_plots = False # Set true only for width/height < 20px and rotation_step = 90° (Very resource intensive)

# Occupancy Grid
occupancy_grid = generate_empty_occupancy_grid(
    width=17,
    length=17
)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=3,
    length=3,
    x=7,
    y=7)

fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()

print(occupancy_grid)

# %% [markdown]
# ### Oscillations with attractive & repulsive potential

# %%
# robot model plots

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Robotermaße
robot_width = 2
robot_length = 3

# Rotationsgranularität
rotation_step = 45

# Start- und Zielpunkt festlegen
start_point = (3, 13, 0)
goal_point = (14, 3, 0)


# Potenzialfunktionen
wavefront_potential_function = False
attraction_repulsion_potential_function = True
attraction_weight= 4
repulsion_weight= 0.025

# Plots
optional_plots = True # Set true only for width/height <= 30px and rotation_step >= 30° (Very resource intensive)
gradient_decent_plots = False # Set true only for width/height < 20px and rotation_step = 90° (Very resource intensive)

# Occupancy Grid
occupancy_grid_width = 7
occupancy_grid_length = 7
occupancy_grid = generate_empty_occupancy_grid(width=occupancy_grid_width,length=occupancy_grid_length)

# Obstacles
#occupancy_grid = add_obstacle(
#    occupancy_grid=occupancy_grid,
#    width=3,
#    length=3,
#    x=8,
#    y=8)

current_position=(4, 3, 0)

fig = plt.figure(figsize=(8, 6))
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    current_position=current_position, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    rotation_step=rotation_step,
    plot_title="")

plt.show()




current_position_rotation=(3, 3, 0)

path_rotation = [(3, 3, 5),(3, 3, 5),(3, 3, 5),(3, 3, 5)]
#for i in range(9):
#    path_rotation.append((3, 3, i))
#    path_rotation.append((3, 3, i))
#    path_rotation.append((3, 3, i))
#    path_rotation.append((3, 3, i))

fig = plt.figure(figsize=(8, 6))
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    current_position=current_position_rotation, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    path=path_rotation,
    rotation_step=rotation_step,
    plot_title="")

plt.show()




current_position_rotation2=(5, 5, 0)

# Occupancy Grid
occupancy_grid_width = 11
occupancy_grid_length = 11
occupancy_grid_rot = generate_empty_occupancy_grid(width=occupancy_grid_width,length=occupancy_grid_length)

path_rotation = []
for i in range(9):
    path_rotation.append((5, 5, i))
    path_rotation.append((5, 5, i))
    path_rotation.append((5, 5, i))
    path_rotation.append((5, 5, i))

fig = plt.figure(figsize=(8, 6))
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid_rot, 
    current_position=current_position_rotation2, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    path=path_rotation,
    rotation_step=rotation_step)

plt.show()






current_position_translation_y=(3, 4, 0)

path_translation= [(3, 1, 0),(3, 1, 0),(3, 1, 0),(3, 1, 0)]

for i in range(1,2):
    path_translation.append((3+i, 1, 0))
    path_translation.append((3+i, 1, 0))
    path_translation.append((3+i, 1, 0))
    path_translation.append((3+i, 1, 0))

for i in range(1,3):
    path_translation.append((3, 1+i, 0))
    path_translation.append((3, 1+i, 0))
    path_translation.append((3, 1+i, 0))
    path_translation.append((3, 1+i, 0))

fig = plt.figure(figsize=(8, 6))
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    #current_position=current_position_rotation, 
    current_position=current_position_translation_y, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    #path=path_rotation,
    path=path_translation,
    rotation_step=rotation_step,
    plot_title="")

current_color = 'orange'
current_rect = plt.Rectangle(
    (5-0.5, 1-0.5),
    robot_width,
    robot_length,
    rotation_point=(5, 1),
    angle=0 * -rotation_step,  # Rotation in Grad umrechnen
    color=current_color,
    label='Current Position'
)
plot_axis.add_patch(current_rect)
plot_axis.scatter(5, 1, color='black', marker='x', label='Rotation Anchor')

plt.show()

#print(occupancy_grid)

# %%
# 2x3 Robot, 45° Rotation, 18x18 Occu. Grid, 1 Obstacle in middle (Demonstrates oscillation with attractive & repulsive potential)

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Robotermaße
robot_width = 2
robot_length = 3

# Rotationsgranularität
rotation_step = 45

# Start- und Zielpunkt festlegen
start_point = (2, 13, 0)
goal_point = (14, 2, 0)
current_position=start_point

# Potenzialfunktionen
wavefront_potential_function = True
attraction_repulsion_potential_function = False
attraction_weight= 5
repulsion_weight= 0

# Plots
optional_plots = True # Set true only for width/height <= 30px and rotation_step >= 30° (Very resource intensive)
gradient_decent_plots = False # Set true only for width/height < 20px and rotation_step = 90° (Very resource intensive)

# Occupancy Grid
occupancy_grid_width = 18
occupancy_grid_length = 18
occupancy_grid = generate_empty_occupancy_grid(width=occupancy_grid_width,length=occupancy_grid_length)

# Obstacles
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=2,
    length=2,
    x=8,
    y=8)

fig = plt.figure(figsize=(8, 6))
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    current_position=current_position, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 2x3 Robot, 45° Rotation, 21x21 Occu. Grid, 1 Obstacle in middle (Demonstrates oscillation with attractive & repulsive potential)

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Robotermaße
robot_width = 2
robot_length = 3

# Rotationsgranularität
rotation_step = 45

# Start- und Zielpunkt festlegen
start_point = (4, 14, 0)
goal_point = (15, 4, 0)
current_position=start_point

# Potenzialfunktionen
wavefront_potential_function = False
attraction_repulsion_potential_function = True
attraction_weight= 4.5
repulsion_weight= 0.05

# Plots
optional_plots = True # Set true only for width/height <= 30px and rotation_step >= 30° (Very resource intensive)
gradient_decent_plots = False # Set true only for width/height < 20px and rotation_step = 90° (Very resource intensive)

# Occupancy Grid
occupancy_grid_width = 21
occupancy_grid_length = 21
occupancy_grid = generate_empty_occupancy_grid(width=occupancy_grid_width,length=occupancy_grid_length)

# Obstacles
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=3,
    length=3,
    x=9,
    y=9)

fig = plt.figure(figsize=(8, 6))
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    current_position=current_position, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x00000174A1B6D100>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 2x3 Robot, 45° Rotation, 42x42 Occu. Grid, 1 Obstacle in middle, (No oscillation with attractive & repulsive potential and upsized occupancy grid)

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Robotermaße
robot_width = 2
robot_length = 3

# Rotationsgranularität
rotation_step = 45

# Start- und Zielpunkt festlegen
start_point = (8, 28, 0)
goal_point = (30, 8, 0)
current_position=start_point

# Potenzialfunktionen
wavefront_potential_function = False
attraction_repulsion_potential_function = True
attraction_weight= 4.5
repulsion_weight= 0.05

# Plots
optional_plots = False # Set true only for width/height <= 30px and rotation_step >= 30° (Very resource intensive)
gradient_decent_plots = False # Set true only for width/height < 20px and rotation_step = 90° (Very resource intensive)

# Occupancy Grid
occupancy_grid_width = 42
occupancy_grid_length = 42
occupancy_grid = generate_empty_occupancy_grid(width=occupancy_grid_width,length=occupancy_grid_length)

# Obstacles
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=6,
    length=6,
    x=18,
    y=18)

fig = plt.figure(figsize=(8, 6))
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    current_position=current_position, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x00000174A21CF2E0>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Convex obstacles with attractive & repulsive potential

# %%
# 2x3 Robot, 90° Rotation, 21x21 Occu. Grid, convex "<"-shaped Obstacle in middle (Demonstrates local minimum with attractive & repulsive potential)

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Robotermaße
robot_width = 2
robot_length = 3


# Rotationsgranularität
rotation_step = 45

# Start- und Zielpunkt festlegen
start_point = (4, 14, 0)
goal_point = (15, 4, 0)
current_position=start_point

# Potenzialfunktionen
wavefront_potential_function = False
attraction_repulsion_potential_function = True
attraction_weight= 3
repulsion_weight= 1

# Plots
optional_plots = True # Set true only for width/height <= 30px and rotation_step >= 30° (Very resource intensive)
gradient_decent_plots = False # Set true only for width/height < 20px and rotation_step = 90° (Very resource intensive)

# Occupancy Grid
occupancy_grid_width = 21
occupancy_grid_length = 21
occupancy_grid = generate_empty_occupancy_grid(width=occupancy_grid_width,length=occupancy_grid_length)

# Obstacles
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=4,
    length=1,
    x=8,
    y=9)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=1,
    length=5,
    x=12,
    y=9)

fig = plt.figure(figsize=(8, 6))
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    current_position=current_position, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x00000174A258D280>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Convex obstacles with wavefront

# %%
# 2x3 Robot, 90° Rotation, 21x21 Occu. Grid, convex "<"-shaped Obstacle in middle (Demonstrates local minimum with attractive & repulsive potential)

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Robotermaße
robot_width = 2
robot_length = 3


# Rotationsgranularität
rotation_step = 45

# Start- und Zielpunkt festlegen
start_point = (4, 14, 0)
goal_point = (15, 4, 0)
current_position=start_point

# Potenzialfunktionen
wavefront_potential_function = True
attraction_repulsion_potential_function = False
# attraction_weight = ...
# repulsion_weight = ...

# Plots
optional_plots = True # Set true only for width/height <= 30px and rotation_step >= 30° (Very resource intensive)
gradient_decent_plots = False # Set true only for width/height < 20px and rotation_step = 90° (Very resource intensive)

# Occupancy Grid
occupancy_grid_width = 21
occupancy_grid_length = 21
occupancy_grid = generate_empty_occupancy_grid(width=occupancy_grid_width,length=occupancy_grid_length)

# Obstacles
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=4,
    length=1,
    x=8,
    y=9)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=1,
    length=5,
    x=12,
    y=9)

fig = plt.figure(figsize=(8, 6))
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    current_position=current_position, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x00000174A241E4F0>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 1x1 Robot, 90° Rotation, 18x18 Occu. Grid, Trapped in "<" (Wavefront recommended)

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Robotermaße
robot_width = 1
robot_length = 1

# Rotationsgranularität
rotation_step = 90

# Start- und Zielpunkt festlegen
start_point = (7, 9, 0)
goal_point = (10, 6, 2)
current_position=start_point

# Potenzialfunktionen
wavefront_potential_function = True
attraction_repulsion_potential_function = False
# attraction_weight= ...
# repulsion_weight= ...

# Plots
optional_plots = True # Set true only for width/height <= 30px and rotation_step >= 30° (Very resource intensive)
gradient_decent_plots = False # Set true only for width/height < 20px and rotation_step = 90° (Very resource intensive)

# Obstacles
occupancy_grid = generate_empty_occupancy_grid(
    length=18,
    width=18
)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=5,
    length=1,
    x=4,
    y=7)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=1,
    length=5,
    x=9,
    y=8)

fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    current_position=current_position, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x00000174A27C9AC0>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Smaller rotation steps & complex occupancy grids

# %%
# 1x3 Robot, 45° Rotation, 18x18 Occu. Grid, Flipped + closed "U" (Wavefront recommended)

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Roboterdimensionen
robot_width = 1
robot_length = 3

# Rotationsgranularität
rotation_step = 45

# Start- und Zielpunkt festlegen
start_point = (12, 8, 0)
goal_point = (15, 10, 4)
current_position=start_point

# Potenzialfunktionen
wavefront_potential_function = True
attraction_repulsion_potential_function = False
# attraction_weight= ...
# repulsion_weight= ...

# Plots
optional_plots = True # Set true only for width/height <= 30px and rotation_step >= 30° (Very resource intensive)
gradient_decent_plots = False # Set true only for width/height < 20px and rotation_step = 90° (Very resource intensive)

# Obstacles
occupancy_grid = generate_empty_occupancy_grid(
    length=18,
    width=18
)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=10,
    length=1,
    x=4,
    y=1)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=1,
    length=15,
    x=13,
    y=1)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=10,
    length=1,
    x=4,
    y=16)

fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    current_position=current_position, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x00000174A266EF40>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 1x3 Robot, 45° Rotation, 18x18 Occu. Grid, Flipped + opened "U" (Wavefront recommended)

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Robotermaße
robot_width = 1
robot_length = 3

# Rotationsgranularität
rotation_step = 45

# Start- und Zielpunkt festlegen
start_point = (12, 8, 0)
goal_point = (15, 10, 4)
current_position=start_point

# Potenzialfunktion
wavefront_potential_function = True
attraction_repulsion_potential_function = False
# attraction_weight= ...
# repulsion_weight= ...

# Obstacles
occupancy_grid = generate_empty_occupancy_grid(
    length=18,
    width=18
)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=8,
    length=1,
    x=4,
    y=1)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=1,
    length=16,
    x=13,
    y=1)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=8,
    length=1,
    x=4,
    y=16)

fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    current_position=current_position, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x00000174A2756B50>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 1x5 Robot, 30° Rotation, 18x18 Occu. Grid, Gap in "|" (Wavefront recommended)

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

robot_width = 1
robot_length = 5

# Rotationsgranularität
rotation_step = 30

# Start- und Zielpunkt festlegen
start_point = (5, 2, 0)
goal_point = (12, 15,6)
current_position= start_point

# Potenzialfunktion
wavefront_potential_function = True
attraction_repulsion_potential_function = False
# attraction_weight= ...
# repulsion_weight= ...

# Plots
optional_plots = True # Set true only for width/height <= 30px and rotation_step >= 30° (Very resource intensive)
gradient_decent_plots = False # Set true only for width/height < 20px and rotation_step = 90° (Very resource intensive)

# Occupancy Grid
occupancy_grid = generate_empty_occupancy_grid(
    length=18,
    width=18
)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=1,
    length=5,
    x=8,
    y=2)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=1,
    length=5,
    x=8,
    y=11)

fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    current_position=current_position, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x00000174A26567F0>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 3x5 Robot, 45° Rotation, 20x12 Occu. Grid, Multiple narrow spots (Wavefront recommended)

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

robot_width = 3
robot_length = 5

# Rotationsgranularität
rotation_step = 45

# Start- und Zielpunkt festlegen
start_point = (0, 0, 0)
goal_point = (14, 10, 2)
current_position=start_point

# Potenzialfunktion
wavefront_potential_function = True
attraction_repulsion_potential_function = False
# attraction_weight= ...
# repulsion_weight= ...

# Plots
optional_plots = True # Set true only for width/height <= 30px and rotation_step >= 30° (Very resource intensive)
gradient_decent_plots = False # Set true only for width/height < 20px and rotation_step = 90° (Very resource intensive)

# Obstacles
occupancy_grid = generate_empty_occupancy_grid(width=20, length=12)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=1,
    length=6,
    x=5,
    y=0)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=1,
    length=3,
    x=5,
    y=10)
    

occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=1,
    length=7,
    x=12,
    y=4)

occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=4,
    length=1,
    x=12,
    y=5)

fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    current_position=current_position, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x00000174A8B866D0>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Scaling up the Occupancy Grid

# %%
# 3x5 Robot, 10° Rotation, 20x12 Occu. Grid, Multiple narrow spots + Robot occlusion with obstacles (Wavefront recommended)

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

robot_width = 3
robot_length = 5

# Rotationsgranularität
rotation_step = 10

# Start- und Zielpunkt festlegen
start_point = (0, 0, 0)
goal_point = (14, 10, 9)
current_position=start_point

# Potenzialfunktion
wavefront_potential_function = True
attraction_repulsion_potential_function = False
# attraction_weight= ...
# repulsion_weight= ...

# Plots
optional_plots = False # Set true only for width/height <= 30px and rotation_step >= 30° (Very resource intensive)
gradient_decent_plots = False # Set true only for width/height < 20px and rotation_step = 90° (Very resource intensive)

# Obstacles
occupancy_grid = generate_empty_occupancy_grid(width=20, length=12)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=1,
    length=6,
    x=5,
    y=0)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=1,
    length=3,
    x=5,
    y=10)
    

occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=1,
    length=7,
    x=12,
    y=4)

occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=4,
    length=1,
    x=12,
    y=5)

fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    current_position=current_position, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x00000174A8D9E5B0>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 6x10 Robot, 10° Rotation, 40x25 Occu. Grid, Multiple narrow spots (Wavefront recommended)

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

robot_width = 6
robot_length = 10

# Rotationsgranularität
rotation_step = 10

# Start- und Zielpunkt festlegen
start_point = (0, 0, 0)
goal_point = (28, 23, 9)
current_position=start_point

# Potenzialfunktion
wavefront_potential_function = True
attraction_repulsion_potential_function = False
# attraction_weight= ...
# repulsion_weight= ...

# Plots
optional_plots = False # Set true only for width/height <= 30px and rotation_step >= 30° (Very resource intensive)
gradient_decent_plots = False # Set true only for width/height < 20px and rotation_step = 90° (Very resource intensive)

# Obstacles
occupancy_grid = generate_empty_occupancy_grid(width=40, length=25)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=2,
    length=12,
    x=10,
    y=0)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=2,
    length=5,
    x=10,
    y=20)
    

occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=2,
    length=15,
    x=24,
    y=8)

occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=8,
    length=2,
    x=24,
    y=10)

fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    current_position=current_position, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x00000174A8E796A0>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 12x20 Robot, 10° Rotation, 80x50 Occu. Grid, Multiple narrow spots (Wavefront recommended, computation takes ~2 min)

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

robot_width = 12
robot_length = 20

# Rotationsgranularität
rotation_step = 30

# Potenzialfunktion
wavefront_potential_function = True
attraction_repulsion_potential_function = False
# attraction_weight= ...
# repulsion_weight= ...

# Plots
optional_plots = False # Set true only for width/height <= 30px and rotation_step >= 30° (Very resource intensive)
gradient_decent_plots = False # Set true only for width/height < 20px and rotation_step = 90° (Very resource intensive)

# Start- und Zielpunkt festlegen
start_point = (0, 0, 0)
goal_point = (56, 47, 3)
current_position=start_point

# Obstacles
occupancy_grid = generate_empty_occupancy_grid(width=80, length=50)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=4,
    length=24,
    x=20,
    y=0)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=4,
    length=10,
    x=20,
    y=40)
    

occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=4,
    length=30,
    x=48,
    y=16)

occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=16,
    length=4,
    x=48,
    y=20)

fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    current_position=current_position, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x00000174A8B8D100>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 24x40 Robot, 5° Rotation, 160x100 Occu. Grid, Multiple narrow spots (Wavefront recommended, computation takes ~5 min)

# %matplotlib widget
import matplotlib.pyplot as plt
from occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

robot_width = 24
robot_length = 40

# Rotationsgranularität
rotation_step = 5

# Start- und Zielpunkt festlegen
start_point = (0, 0, 0)
goal_point = (112, 94, 18)
current_position=start_point

# Potenzialfunktionen
wavefront_potential_function = True
attraction_repulsion_potential_function = False
# attraction_weight= ...
# repulsion_weight= ...

# Plots
optional_plots = False # Set true only for width/height <= 30px and rotation_step >= 30° (Very resource intensive)
gradient_decent_plots = False # Set true only for width/height < 20px and rotation_step = 90° (Very resource intensive)

# Obstacles
occupancy_grid = generate_empty_occupancy_grid(width=160, length=100)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=8,
    length=48,
    x=40,
    y=0)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=8,
    length=20,
    x=40,
    y=80)
    

occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=8,
    length=60,
    x=96,
    y=32)

occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    width=32,
    length=8,
    x=96,
    y=40)

fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    current_position=current_position, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x00000174AAC25460>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # 2) Computations

# %%
# Compute Configuration Space
from configuration_space import compute_configuration_space
configuration_space = compute_configuration_space(
    robot_length=robot_length, 
    robot_width=robot_width, 
    rotation_step=rotation_step, 
    occupancy_grid=occupancy_grid)

# Compute potentials
from potential import compute_potential_attraction_repulsion, compute_potential_wavefront
import warnings
if attraction_repulsion_potential_function is not None and attraction_repulsion_potential_function == True:
    if wavefront_potential_function is not None and wavefront_potential_function == True:
        warnings.warn("both 'attraction_repulsion_potential_function' and 'wavefront_potential_function' = True")
    if attraction_weight is None or repulsion_weight is None:
        raise Exception("Please set both the 'attraction_weight' and 'repulsion_weight'")
    print("Potential function: attractive & repulsive potential")
    attractive_potential, repulsive_potential = compute_potential_attraction_repulsion(
        configuration_space=configuration_space,
        goal=goal_point,
        attraction_weight=attraction_weight, 
        repulsion_weight=repulsion_weight
    )
    potential = attractive_potential + repulsive_potential
    potential[goal_point[2],goal_point[1],goal_point[0]] = 0
elif wavefront_potential_function is not None and wavefront_potential_function == True:
    if attraction_repulsion_potential_function is not None and attraction_repulsion_potential_function == True:
        warnings.warn("both 'attraction_repulsion_potential_function' and 'wavefront_potential_function' = True")
    print("Potential function: wavefront potential")
    potential_0, potential_650, potential_1250, potential = compute_potential_wavefront(
        configuration_space=configuration_space,
        goal=goal_point
    )
else:
    raise Exception("Please choose exactly one potential function by setting either 'wavefront_potential_function' or 'attraction_repulsion_potential_function' = True")

# Compute Gradients
from gradients import compute_gradients, compute_obstacle_gradients, fix_local_maxima
force_field_x, force_field_y, force_field_rotation = compute_gradients(potential, goal_point)
compute_obstacle_gradients(force_field_x, force_field_y, force_field_rotation, potential)
fix_local_maxima(force_field_x, force_field_y, force_field_rotation, potential, goal_point)
# Out:
# Potential function: attractive & repulsive potential
# e:\.Persönliche Dateien\.Studium\.Master\CASE\ROB\potentialfeld\potential-field\gradients.py:174: UserWarning: Local force minima or plateau at: [[ 2  1 13]]
#   warnings.warn("Local force minima or plateau at: " + str(local_extrema_after))

# %% [markdown]
# # 3) Plots (optional)

# %%
if not optional_plots:
    raise Exception("For this scenario, plots will be very CPU intensive. Comment out this line to proceed nevertheless. ")


# Plot Expanded Occupancy Grids
from occupancy_grid import plot_occupancy_grid
import numpy as np

rotations = np.arange(0, 360, rotation_step)
fig = plt.figure(figsize=(13, len(rotations)))
fig.suptitle('Expanded Occupancy Grids')
for index, rotation in enumerate(rotations):      
    ax_occupancy_grid = fig.add_subplot(int(np.ceil(len(rotations)/4)), 4, index+1)
    plot_occupancy_grid(
        occupancy_grid=configuration_space[index], 
        goal_point=goal_point, 
        plot_axis=ax_occupancy_grid, 
        start_point=start_point,
        plot_title="Expanded Occupancy Grid\n" + str(rotation) + "° Rotation",
        ticks=False,
        rotation_step = rotation_step)
plt.show()


# Plot 3D Configuration Space
import numpy as np
import matplotlib.pyplot as plt
from configuration_space import plot_configuration_space

fig = plt.figure(figsize=(13, 8))
fig.suptitle('3D Configuration Space')
plot_axis = fig.add_subplot(111, projection='3d')
plot_configuration_space(
    configuration_space=configuration_space, 
    goal_point=goal_point,
    start_point=start_point,
    rotation_step=rotation_step,
    ax=plot_axis)
plt.show()

# Plot Potential
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from potential import plot_potential_stacked, plot_potential_slice

'''
fig = plt.figure(figsize=(5.5,5.5))
ax_potential_0deg = fig.add_subplot(111, projection='3d')
plot_potential_slice(attractive_potential[0], 'Attractive Potential\nfor ' + str(0) + '° Rotation', ax_potential_0deg, 0.8,normalize=False)
plt.show()

fig = plt.figure(figsize=(5.5,5.5))
ax_potential_0deg = fig.add_subplot(111, projection='3d')
plot_potential_slice(repulsive_potential[0], 'Repulsive Potential\nfor ' + str(0) + '° Rotation', ax_potential_0deg, 0.5,normalize=False)
plt.show()

fig = plt.figure(figsize=(5.5,5.5))
ax_potential_0deg = fig.add_subplot(111, projection='3d')
plot_potential_slice(potential[0], 'Total Potential\nfor ' + str(0) + '° Rotation', ax_potential_0deg, 0.8,normalize=False)
plt.show()
'''

'''
max_pot = np.max(np.nan_to_num(potential[0]))

fig = plt.figure(figsize=(5.5,5.5))
ax_potential_0deg = fig.add_subplot(111, projection='3d')
plot_potential_slice(potential_0[0], 'Wavefront Potential for\n' + str(0) + '° Rotation (0 Iterations)', ax_potential_0deg, 0.8,False,max_pot)
plt.show()

fig = plt.figure(figsize=(5.5,5.5))
ax_potential_0deg = fig.add_subplot(111, projection='3d')
plot_potential_slice(potential_650[0], 'Wavefront Potential for\n' + str(0) + '° Rotation (~650 Iterations)', ax_potential_0deg, 0.8,False,max_pot)
plt.show()

fig = plt.figure(figsize=(5.5,5.5))
ax_potential_0deg = fig.add_subplot(111, projection='3d')
plot_potential_slice(potential_1250[0], 'Wavefront Potential for\n' + str(0) + '° Rotation (~1250 Iterations)', ax_potential_0deg, 0.8,False,max_pot)
plt.show()

fig = plt.figure(figsize=(5.5,5.5))
ax_potential_0deg = fig.add_subplot(111, projection='3d')
plot_potential_slice(potential[0], 'Wavefront Potential for\n' + str(0) + '° Rotation (~1850 Iterations)', ax_potential_0deg, 0.8,False,max_pot)
plt.show()
'''

rotations = np.arange(0, 360, rotation_step)
fig = plt.figure(figsize=(13, 4 + len(rotations)))
fig.suptitle('Potential (Stacked and per Rotation Layer)')
ax_potential_stacked = fig.add_subplot(1 + int(np.ceil(len(rotations)/4)), 4, (2,3), projection='3d')
plot_potential_stacked(potential, 'Potential (all Rotations)', ax_potential_stacked, rotation_step, 0.8)
for index, rotation in enumerate(rotations):  
    ax_potential_slice = fig.add_subplot(1 + int(np.ceil(len(rotations)/4)), 4, 5 + index, projection='3d')
    plot_potential_slice(potential[index], 'Potential for ' + str(rotation) + '° Rotation', ax_potential_slice, 0.8)
plt.subplots_adjust(wspace=0.3,hspace=0)
plt.show()

# Plot Gradients ("Force Field")

from configuration_space import plot_configuration_space

fig = plt.figure(figsize=(13, 8))
fig.suptitle('Force Field (Gradients)')
plot_axis = fig.add_subplot(111, projection='3d')
plot_configuration_space(
    configuration_space=configuration_space, 
    force_field_x=force_field_x, 
    force_field_y=force_field_y, 
    force_field_rotation=force_field_rotation, 
    goal_point=goal_point, 
    start_point=start_point,
    ax=plot_axis,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # 4) Gradient Descent Preparation

# %%
from gradients import update_gradient_descent_plots
import numpy as np
from time import sleep
from gradients import gradient_descent_step

if gradient_decent_plots:
    rotations = np.arange(0, 360, rotation_step)
else:
    rotations = []

fig = plt.figure(figsize=(13, 5 + len(rotations)))

if gradient_decent_plots:
    ax_cs_2D = []
    for index, rotation in enumerate(rotations):      
        ax_cs_2D.append(fig.add_subplot(1 + int(np.ceil(len(rotations)/4)), 4, 4 + index+1))
    ax_cs_3D = fig.add_subplot(1 + int(np.ceil(len(rotations)/4)), 4, (3,4), projection='3d')
else:
    ax_cs_2D = []    
    ax_cs_3D = None

ax_occupancy_grid = fig.add_subplot(1 + int(np.ceil(len(rotations)/4)), 4, (1,2))

path = []

update_gradient_descent_plots(
        occupancy_grid=occupancy_grid,
        configuration_space=configuration_space,
        start_point=start_point,
        goal_point=goal_point,
        current_position=current_position,
        robot_width=robot_width,
        robot_length=robot_length,
        rotation_step=rotation_step,
        ax_occupancy_grid=ax_occupancy_grid,
        ax_cs_2D=ax_cs_2D,
        ax_cs_3D=ax_cs_3D,
        force_field_x=force_field_x,
        force_field_y=force_field_y,
        force_field_rotation=force_field_rotation,
        gradient_decent_plots=gradient_decent_plots,
        path=path)

fig.suptitle('Please execute cell below')
plt.subplots_adjust(wspace=0.3,hspace=0)

fig.canvas.draw()
# Out:
# np.count_nonzero(occupancy_grid) > 0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # 5) Gradient Descent Execution (Watch figure above!)

# %%
fig.suptitle("Descending Gradients ...")

try:
    while True:
        current_position = gradient_descent_step(
                            current_position=current_position,
                            force_field_x=force_field_x,
                            force_field_y=force_field_y,
                            force_field_rotation=force_field_rotation,
                            path=path,
                            goal_point=goal_point)  

        update_gradient_descent_plots(
            occupancy_grid=occupancy_grid,
            configuration_space=configuration_space,
            start_point=start_point,
            goal_point=goal_point,
            current_position=current_position,
            robot_width=robot_width,
            robot_length=robot_length,
            rotation_step=rotation_step,
            ax_occupancy_grid=ax_occupancy_grid,
            ax_cs_2D=ax_cs_2D,
            ax_cs_3D=ax_cs_3D,
            force_field_x=force_field_x,
            force_field_y=force_field_y,
            force_field_rotation=force_field_rotation,
            gradient_decent_plots=gradient_decent_plots,
            path=path)
        
        sleep(0.05)
        fig.canvas.draw()
except Exception as e:
    fig.suptitle(e)
# Out:
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
# np.count_nonzero(occupancy_grid) > 0
