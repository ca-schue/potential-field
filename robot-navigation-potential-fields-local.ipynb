# %% [markdown]
# # 0) Abhängigkeiten installieren (Neustart erforderlich)

# %%
# %pip install -r requirements.txt

# %% [markdown]
# # 1) Szenario auswählen oder abändern

# %% [markdown]
# ### "Good Case" für anziehendes & abstoßendes Potenzial

# %%
# Szenario "Anziehendes & abstoßendes Potenzial": 1x2 Roboter - 45° Rotationsschritte - 17x17 Occu.Grid - 3x3 Hindernis in Mitte

# Imports (nicht verändern)
# %matplotlib widget
import matplotlib.pyplot as plt
from functions.occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Dimensionen Roboter
robot_width = 1 # Breite in X-Richtung
robot_length = 2 # Länge in Y-Richtung

# Rotationsschritte (Grad)
rotation_step = 45 

# Start- und Zielpunkt festlegen: (X,Y,Rotationzustand) 
# => Rotation in Grad = Rotationzustand * 'rotation_step'
start_point = (2, 13, 0)
goal_point = (13, 3, 0)
current_position=start_point # Initialisierung der aktuellen Position

# Potenzialfunktion (disjunkte Auswahl)
wavefront_potential_function = False
attraction_repulsion_potential_function = True
attraction_weight = 2 # Nur relevant für 'attr._repul._pot._function = True'
repulsion_weight = 0 # Nur relevant für 'attr._repul._pot._function = True'

# Dimensionen Occupancy Grid
occupancy_grid_width = 17 # Breite des Occupancy Grid in X-Richtung
occupancy_grid_length = 17 # Länge des Occupancy Grid in Y-Richtung
occupancy_grid = generate_empty_occupancy_grid(
    occupancy_grid_width=occupancy_grid_width,
    occupancy_grid_length=occupancy_grid_length
)

# Hindernisse im Occupancy Grid: 
# Aufgespanntes Rechteck von x bis x + 'obstacle_width'  und y bis y + 'obstacle_length'
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=3,
    obstacle_length=3,
    x=7,
    y=7)

# Berechnung der Plots für 3) und 4) aktivieren bzw. deaktivieren wenn CPU-intensiv
optional_plots = True # Nicht empfohlen für Occu. Grid. w/h > 30 oder rotation_step < 30 
gradient_decent_plots = False # Nicht empfohlen für Occu. Grid. w/h > 20 oder rotation_step < 90

# Initialisiertes Szenario anzeigen (nicht verändern)
fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Oszillationen bei anziehendem & abstoßenden Potenzial

# %%
# Szenario "Oszillationen bei anziehendem & abstoßenden Potenzial": 2x3 Roboter - 45° Rotationsschritte - 18x18 Occu.Grid - 3x3 Hindernis in Mitte

# Imports (nicht verändern)
# %matplotlib widget
import matplotlib.pyplot as plt
from functions.occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Dimensionen Roboter
robot_width = 2 # Breite in X-Richtung
robot_length = 3 # Länge in Y-Richtung

# Rotationsschritte (Grad)
rotation_step = 45 

# Start- und Zielpunkt festlegen: (X,Y,Rotationzustand) => Rotation in Grad = Rotationzustand * 'rotation_step'
start_point = (2, 13, 0)
goal_point = (14, 2, 0)
current_position=start_point # Initialisierung der aktuellen Position

# Potenzialfunktion (disjunkte Auswahl)
wavefront_potential_function = False
attraction_repulsion_potential_function = True
attraction_weight = 3 # Nur relevant für 'attraction_repulsion_potential_function = True'
repulsion_weight = 0 # Nur relevant für 'attraction_repulsion_potential_function = True'

# Dimensionen Occupancy Grid
occupancy_grid_width = 18 # Breite des Occupancy Grid in X-Richtung
occupancy_grid_length = 18 # Länge des Occupancy Grid in Y-Richtung
occupancy_grid = generate_empty_occupancy_grid(
    occupancy_grid_width=occupancy_grid_width,
    occupancy_grid_length=occupancy_grid_length
)

# Hindernisse im Occupancy Grid: Aufgespanntes Rechteck von x bis x + 'obstacle_width'  und y bis y + 'obstacle_length'.
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=2,
    obstacle_length=2,
    x=8,
    y=8)

# Berechnung der Plots aktivieren bzw. deaktivieren wenn CPU-intensiv
optional_plots = True # Plots in 3) nicht empfohlen für occupancy_grid_width/height > 30 und rotation_step < 30 
gradient_decent_plots = False # Plots in 4) nicht empfohlen für occupancy_grid_width/height > 20 und rotation_step < 90

# Initialisiertes Szenario anzeigen (nicht verändern)
fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Szenario "Keine Oszillationen bei anziehendem & abstoßenden Potenzial durch größeres Occu.Grid": 2x3 Roboter - 45° Rotationsschritte - 42x42 Occu.Grid - 6x6 Hindernis in Mitte

# Imports (nicht verändern)
# %matplotlib widget
import matplotlib.pyplot as plt
from functions.occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Dimensionen Roboter
robot_width = 2 # Breite in X-Richtung
robot_length = 3 # Länge in Y-Richtung

# Rotationsschritte (Grad)
rotation_step = 45 

# Start- und Zielpunkt festlegen: (X,Y,Rotationzustand) => Rotation in Grad = Rotationzustand * 'rotation_step'
start_point = (8, 28, 0)
goal_point = (30, 8, 0)
current_position=start_point # Initialisierung der aktuellen Position

# Potenzialfunktion (disjunkte Auswahl)
wavefront_potential_function = False
attraction_repulsion_potential_function = True
attraction_weight= 4.5 # Nur relevant für 'attraction_repulsion_potential_function = True'
repulsion_weight= 0.05 # Nur relevant für 'attraction_repulsion_potential_function = True'

# Dimensionen Occupancy Grid
occupancy_grid_width = 42 # Breite des Occupancy Grid in X-Richtung
occupancy_grid_length = 42 # Länge des Occupancy Grid in Y-Richtung
occupancy_grid = generate_empty_occupancy_grid(
    occupancy_grid_width=occupancy_grid_width,
    occupancy_grid_length=occupancy_grid_length
)

# Hindernisse im Occupancy Grid: Aufgespanntes Rechteck von x bis x + 'obstacle_width'  und y bis y + 'obstacle_length'.
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=6,
    obstacle_length=6,
    x=18,
    y=18)

# Berechnung der Plots aktivieren bzw. deaktivieren wenn CPU-intensiv
optional_plots = False # Plots in 3) nicht empfohlen für occupancy_grid_width/height > 30 und rotation_step < 30 
gradient_decent_plots = False # Plots in 4) nicht empfohlen für occupancy_grid_width/height > 20 und rotation_step < 90

# Initialisiertes Szenario anzeigen (nicht verändern)
fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=False,
    grid=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Konkave Hindernisse bei anziehendem & abstoßenden Potenzial (lokales Minimum)

# %%
# Szenario "Lokales Minimum bei anziehendem & abstoßenden Potenzial": 2x3 Roboter - 45° Rotationsschritte - 21x21 Occu.Grid - Konkaves "<"-Hindernis in Mitte

# Imports (nicht verändern)
# %matplotlib widget
import matplotlib.pyplot as plt
from functions.occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Dimensionen Roboter
robot_width = 2 # Breite in X-Richtung
robot_length = 3 # Länge in Y-Richtung

# Rotationsschritte (Grad)
rotation_step = 45 

# Start- und Zielpunkt festlegen: (X,Y,Rotationzustand) => Rotation in Grad = Rotationzustand * 'rotation_step'
start_point = (4, 14, 0)
goal_point = (15, 4, 0)
current_position=start_point # Initialisierung der aktuellen Position

# Potenzialfunktion (disjunkte Auswahl)
wavefront_potential_function = False
attraction_repulsion_potential_function = True
attraction_weight= 3 # Nur relevant für 'attraction_repulsion_potential_function = True'
repulsion_weight= 1 # Nur relevant für 'attraction_repulsion_potential_function = True'

# Dimensionen Occupancy Grid
occupancy_grid_width = 21 # Breite des Occupancy Grid in X-Richtung
occupancy_grid_length = 21 # Länge des Occupancy Grid in Y-Richtung
occupancy_grid = generate_empty_occupancy_grid(
    occupancy_grid_width=occupancy_grid_width,
    occupancy_grid_length=occupancy_grid_length
)

# Hindernisse im Occupancy Grid: Aufgespanntes Rechteck von x bis x + 'obstacle_width'  und y bis y + 'obstacle_length'.
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=4,
    obstacle_length=1,
    x=8,
    y=9)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=1,
    obstacle_length=5,
    x=12,
    y=9)


# Berechnung der Plots aktivieren bzw. deaktivieren wenn CPU-intensiv
optional_plots = True # Plots in 3) nicht empfohlen für occupancy_grid_width/height > 30 und rotation_step < 30 
gradient_decent_plots = False # Plots in 4) nicht empfohlen für occupancy_grid_width/height > 20 und rotation_step < 90

# Initialisiertes Szenario anzeigen (nicht verändern)
fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=False,
    grid=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Konkave Hindernisse bei Wavefront-Potenzialen (Konvergenz zum Zielpunkt)

# %%
# Szenario "Konvergenz zu Zielpunkt bei Wavefront-Potenzialen": 2x3 Roboter - 45° Rotationsschritte - 21x21 Occu.Grid - Konkaves "<"-Hindernis in Mitte

# Imports (nicht verändern)
# %matplotlib widget
import matplotlib.pyplot as plt
from functions.occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Dimensionen Roboter
robot_width = 2 # Breite in X-Richtung
robot_length = 3 # Länge in Y-Richtung

# Rotationsschritte (Grad)
rotation_step = 45 

# Start- und Zielpunkt festlegen: (X,Y,Rotationzustand) => Rotation in Grad = Rotationzustand * 'rotation_step'
start_point = (4, 14, 0)
goal_point = (15, 4, 0)
current_position=start_point # Initialisierung der aktuellen Position

# Potenzialfunktion (disjunkte Auswahl)
wavefront_potential_function = True
attraction_repulsion_potential_function = False
#attraction_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'
#repulsion_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'

# Dimensionen Occupancy Grid
occupancy_grid_width = 21 # Breite des Occupancy Grid in X-Richtung
occupancy_grid_length = 21 # Länge des Occupancy Grid in Y-Richtung
occupancy_grid = generate_empty_occupancy_grid(
    occupancy_grid_width=occupancy_grid_width,
    occupancy_grid_length=occupancy_grid_length
)

# Hindernisse im Occupancy Grid: Aufgespanntes Rechteck von x bis x + 'obstacle_width'  und y bis y + 'obstacle_length'.
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=4,
    obstacle_length=1,
    x=8,
    y=9)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=1,
    obstacle_length=5,
    x=12,
    y=9)


# Berechnung der Plots aktivieren bzw. deaktivieren wenn CPU-intensiv
optional_plots = True # Plots in 3) nicht empfohlen für occupancy_grid_width/height > 30 und rotation_step < 30 
gradient_decent_plots = False # Plots in 4) nicht empfohlen für occupancy_grid_width/height > 20 und rotation_step < 90

# Initialisiertes Szenario anzeigen (nicht verändern)
fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=False,
    grid=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Szenario "Konvergenz zu Zielpunkt bei Wavefront-Potenzialen": 1x1 Roboter - 90° Rotationsschritte - 18x18 Occu.Grid - Konkaves "<"-Hindernis in Mitte

# Imports (nicht verändern)
# %matplotlib widget
import matplotlib.pyplot as plt
from functions.occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Dimensionen Roboter
robot_width = 1 # Breite in X-Richtung
robot_length = 1 # Länge in Y-Richtung

# Rotationsschritte (Grad)
rotation_step = 90 

# Start- und Zielpunkt festlegen: (X,Y,Rotationzustand) => Rotation in Grad = Rotationzustand * 'rotation_step'
start_point = (7, 9, 0)
goal_point = (10, 6, 2)
current_position=start_point # Initialisierung der aktuellen Position

# Potenzialfunktion (disjunkte Auswahl)
wavefront_potential_function = True
attraction_repulsion_potential_function = False
#attraction_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'
#repulsion_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'

# Dimensionen Occupancy Grid
occupancy_grid_width = 18 # Breite des Occupancy Grid in X-Richtung
occupancy_grid_length = 18 # Länge des Occupancy Grid in Y-Richtung
occupancy_grid = generate_empty_occupancy_grid(
    occupancy_grid_width=occupancy_grid_width,
    occupancy_grid_length=occupancy_grid_length
)

# Hindernisse im Occupancy Grid: Aufgespanntes Rechteck von x bis x + 'obstacle_width'  und y bis y + 'obstacle_length'.
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=5,
    obstacle_length=1,
    x=4,
    y=7)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=1,
    obstacle_length=5,
    x=9,
    y=8)

# Berechnung der Plots aktivieren bzw. deaktivieren wenn CPU-intensiv
optional_plots = True # Plots in 3) nicht empfohlen für occupancy_grid_width/height > 30 und rotation_step < 30 
gradient_decent_plots = False # Plots in 4) nicht empfohlen für occupancy_grid_width/height > 20 und rotation_step < 90

# Initialisiertes Szenario anzeigen (nicht verändern)
fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=False,
    grid=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Kleine Rotationsschritte & komplexe Occupancy Grids (Wavefront)

# %%
# Szenario "Demonstration Wavefront-Potenziale": 1x3 Roboter - 45° Rotationsschritte - 18x18 Occu.Grid - Großes "U"-Hindernis (geöffnet)

# Imports (nicht verändern)
# %matplotlib widget
import matplotlib.pyplot as plt
from functions.occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Dimensionen Roboter
robot_width = 1 # Breite in X-Richtung
robot_length = 3 # Länge in Y-Richtung

# Rotationsschritte (Grad)
rotation_step = 45

# Start- und Zielpunkt festlegen: (X,Y,Rotationzustand) => Rotation in Grad = Rotationzustand * 'rotation_step'
start_point = (12, 8, 0)
goal_point = (15, 10, 4)
current_position=start_point # Initialisierung der aktuellen Position

# Potenzialfunktion (disjunkte Auswahl)
wavefront_potential_function = True
attraction_repulsion_potential_function = False
#attraction_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'
#repulsion_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'

# Dimensionen Occupancy Grid
occupancy_grid_width = 18 # Breite des Occupancy Grid in X-Richtung
occupancy_grid_length = 18 # Länge des Occupancy Grid in Y-Richtung
occupancy_grid = generate_empty_occupancy_grid(
    occupancy_grid_width=occupancy_grid_width,
    occupancy_grid_length=occupancy_grid_length
)

# Hindernisse im Occupancy Grid: Aufgespanntes Rechteck von x bis x + 'obstacle_width'  und y bis y + 'obstacle_length'.
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=10,
    obstacle_length=1,
    x=4,
    y=1)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=1,
    obstacle_length=15,
    x=13,
    y=1)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=10,
    obstacle_length=1,
    x=4,
    y=16)

# Berechnung der Plots aktivieren bzw. deaktivieren wenn CPU-intensiv
optional_plots = True # Plots in 3) nicht empfohlen für occupancy_grid_width/height > 30 und rotation_step < 30 
gradient_decent_plots = False # Plots in 4) nicht empfohlen für occupancy_grid_width/height > 20 und rotation_step < 90

# Initialisiertes Szenario anzeigen (nicht verändern)
fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=False,
    grid=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Szenario "Demonstration Wavefront-Potenziale": 1x3 Roboter - 45° Rotationsschritte - 18x18 Occu.Grid - Großes "U"-Hindernis (geschlossen)

# Imports (nicht verändern)
# %matplotlib widget
import matplotlib.pyplot as plt
from functions.occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Dimensionen Roboter
robot_width = 1 # Breite in X-Richtung
robot_length = 3 # Länge in Y-Richtung

# Rotationsschritte (Grad)
rotation_step = 45

# Start- und Zielpunkt festlegen: (X,Y,Rotationzustand) => Rotation in Grad = Rotationzustand * 'rotation_step'
start_point = (12, 8, 0)
goal_point = (15, 10, 4)
current_position=start_point # Initialisierung der aktuellen Position

# Potenzialfunktion (disjunkte Auswahl)
wavefront_potential_function = True
attraction_repulsion_potential_function = False
#attraction_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'
#repulsion_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'

# Dimensionen Occupancy Grid
occupancy_grid_width = 18 # Breite des Occupancy Grid in X-Richtung
occupancy_grid_length = 18 # Länge des Occupancy Grid in Y-Richtung
occupancy_grid = generate_empty_occupancy_grid(
    occupancy_grid_width=occupancy_grid_width,
    occupancy_grid_length=occupancy_grid_length
)

# Hindernisse im Occupancy Grid: Aufgespanntes Rechteck von x bis x + 'obstacle_width'  und y bis y + 'obstacle_length'.
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=8,
    obstacle_length=1,
    x=4,
    y=1)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=1,
    obstacle_length=16,
    x=13,
    y=1)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=8,
    obstacle_length=1,
    x=4,
    y=16)

# Berechnung der Plots aktivieren bzw. deaktivieren wenn CPU-intensiv
optional_plots = True # Plots in 3) nicht empfohlen für occupancy_grid_width/height > 30 und rotation_step < 30 
gradient_decent_plots = False # Plots in 4) nicht empfohlen für occupancy_grid_width/height > 20 und rotation_step < 90

# Initialisiertes Szenario anzeigen (nicht verändern)
fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=False,
    grid=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Szenario "Demonstration Wavefront-Potenziale": 1x5 Roboter - 30° Rotationsschritte - 18x18 Occu.Grid - "|"-Hindernis mit Spalt

# Imports (nicht verändern)
# %matplotlib widget
import matplotlib.pyplot as plt
from functions.occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Dimensionen Roboter
robot_width = 1 # Breite in X-Richtung
robot_length = 5 # Länge in Y-Richtung

# Rotationsschritte (Grad)
rotation_step = 30

# Start- und Zielpunkt festlegen: (X,Y,Rotationzustand) => Rotation in Grad = Rotationzustand * 'rotation_step'
start_point = (5, 2, 0)
goal_point = (12, 15,6)
current_position=start_point # Initialisierung der aktuellen Position

# Potenzialfunktion (disjunkte Auswahl)
wavefront_potential_function = True
attraction_repulsion_potential_function = False
#attraction_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'
#repulsion_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'

# Dimensionen Occupancy Grid
occupancy_grid_width = 18 # Breite des Occupancy Grid in X-Richtung
occupancy_grid_length = 18 # Länge des Occupancy Grid in Y-Richtung
occupancy_grid = generate_empty_occupancy_grid(
    occupancy_grid_width=occupancy_grid_width,
    occupancy_grid_length=occupancy_grid_length
)

# Hindernisse im Occupancy Grid: Aufgespanntes Rechteck von x bis x + 'obstacle_width'  und y bis y + 'obstacle_length'.
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=1,
    obstacle_length=5,
    x=8,
    y=2)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=1,
    obstacle_length=5,
    x=8,
    y=11)

# Berechnung der Plots aktivieren bzw. deaktivieren wenn CPU-intensiv
optional_plots = True # Plots in 3) nicht empfohlen für occupancy_grid_width/height > 30 und rotation_step < 30 
gradient_decent_plots = False # Plots in 4) nicht empfohlen für occupancy_grid_width/height > 20 und rotation_step < 90

# Initialisiertes Szenario anzeigen (nicht verändern)
fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=False,
    grid=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Szenario "Demonstration Wavefront-Potenziale": 3x5 Roboter - 45° Rotationsschritte - 20x12 Occu.Grid - Labyrinth mit Engstellen

# Imports (nicht verändern)
# %matplotlib widget
import matplotlib.pyplot as plt
from functions.occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Dimensionen Roboter
robot_width = 3 # Breite in X-Richtung
robot_length = 5 # Länge in Y-Richtung

# Rotationsschritte (Grad)
rotation_step = 45

# Start- und Zielpunkt festlegen: (X,Y,Rotationzustand) => Rotation in Grad = Rotationzustand * 'rotation_step'
start_point = (0, 0, 0)
goal_point = (14, 10, 2)
current_position=start_point # Initialisierung der aktuellen Position

# Potenzialfunktion (disjunkte Auswahl)
wavefront_potential_function = True
attraction_repulsion_potential_function = False
#attraction_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'
#repulsion_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'

# Dimensionen Occupancy Grid
occupancy_grid_width = 20 # Breite des Occupancy Grid in X-Richtung
occupancy_grid_length = 12 # Länge des Occupancy Grid in Y-Richtung
occupancy_grid = generate_empty_occupancy_grid(
    occupancy_grid_width=occupancy_grid_width,
    occupancy_grid_length=occupancy_grid_length
)

# Hindernisse im Occupancy Grid: Aufgespanntes Rechteck von x bis x + 'obstacle_width'  und y bis y + 'obstacle_length'.
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=1,
    obstacle_length=6,
    x=5,
    y=0)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=1,
    obstacle_length=3,
    x=5,
    y=10)  
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=1,
    obstacle_length=7,
    x=12,
    y=4)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=4,
    obstacle_length=1,
    x=12,
    y=5)

# Berechnung der Plots aktivieren bzw. deaktivieren wenn CPU-intensiv
optional_plots = True # Plots in 3) nicht empfohlen für occupancy_grid_width/height > 30 und rotation_step < 30 
gradient_decent_plots = False # Plots in 4) nicht empfohlen für occupancy_grid_width/height > 20 und rotation_step < 90

# Initialisiertes Szenario anzeigen (nicht verändern)
fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=False,
    grid=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Skalierung der Dimensionen des Roboters und Occupancy Grid

# %%
# Szenario "Interpolationsartefakte": 3x5 Roboter - 10° Rotationsschritte - 20x12 Occu.Grid - Labyrinth mit Engstellen

# Imports (nicht verändern)
# %matplotlib widget
import matplotlib.pyplot as plt
from functions.occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Dimensionen Roboter
robot_width = 3 # Breite in X-Richtung
robot_length = 5 # Länge in Y-Richtung

# Rotationsschritte (Grad)
rotation_step = 10

# Start- und Zielpunkt festlegen: (X,Y,Rotationzustand) => Rotation in Grad = Rotationzustand * 'rotation_step'
start_point = (0, 0, 0)
goal_point = (14, 10, 9)
current_position=start_point # Initialisierung der aktuellen Position

# Potenzialfunktion (disjunkte Auswahl)
wavefront_potential_function = True
attraction_repulsion_potential_function = False
#attraction_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'
#repulsion_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'

# Dimensionen Occupancy Grid
occupancy_grid_width = 20 # Breite des Occupancy Grid in X-Richtung
occupancy_grid_length = 12 # Länge des Occupancy Grid in Y-Richtung
occupancy_grid = generate_empty_occupancy_grid(
    occupancy_grid_width=occupancy_grid_width,
    occupancy_grid_length=occupancy_grid_length
)

# Hindernisse im Occupancy Grid: Aufgespanntes Rechteck von x bis x + 'obstacle_width'  und y bis y + 'obstacle_length'.
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=1,
    obstacle_length=6,
    x=5,
    y=0)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=1,
    obstacle_length=3,
    x=5,
    y=10)  
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=1,
    obstacle_length=7,
    x=12,
    y=4)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=4,
    obstacle_length=1,
    x=12,
    y=5)

# Berechnung der Plots aktivieren bzw. deaktivieren wenn CPU-intensiv
optional_plots = False # Plots in 3) nicht empfohlen für occupancy_grid_width/height > 30 und rotation_step < 30 
gradient_decent_plots = False # Plots in 4) nicht empfohlen für occupancy_grid_width/height > 20 und rotation_step < 90

# Initialisiertes Szenario anzeigen (nicht verändern)
fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=False,
    grid=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Szenario "Skalierung Dimensionen x2": 6x10 Roboter - 10° Rotationsschritte - 40x25 Occu.Grid - Labyrinth mit Engstellen

# Imports (nicht verändern)
# %matplotlib widget
import matplotlib.pyplot as plt
from functions.occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Dimensionen Roboter
robot_width = 6 # Breite in X-Richtung
robot_length = 10 # Länge in Y-Richtung

# Rotationsschritte (Grad)
rotation_step = 10

# Start- und Zielpunkt festlegen: (X,Y,Rotationzustand) => Rotation in Grad = Rotationzustand * 'rotation_step'
start_point = (0, 0, 0)
goal_point = (28, 23, 9)
current_position=start_point # Initialisierung der aktuellen Position

# Potenzialfunktion (disjunkte Auswahl)
wavefront_potential_function = True
attraction_repulsion_potential_function = False
#attraction_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'
#repulsion_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'

# Dimensionen Occupancy Grid
occupancy_grid_width = 40 # Breite des Occupancy Grid in X-Richtung
occupancy_grid_length = 25 # Länge des Occupancy Grid in Y-Richtung
occupancy_grid = generate_empty_occupancy_grid(
    occupancy_grid_width=occupancy_grid_width,
    occupancy_grid_length=occupancy_grid_length
)

# Hindernisse im Occupancy Grid: Aufgespanntes Rechteck von x bis x + 'obstacle_width'  und y bis y + 'obstacle_length'.
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=2,
    obstacle_length=12,
    x=10,
    y=0)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=2,
    obstacle_length=5,
    x=10,
    y=20)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=2,
    obstacle_length=15,
    x=24,
    y=8)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=8,
    obstacle_length=2,
    x=24,
    y=10)

# Berechnung der Plots aktivieren bzw. deaktivieren wenn CPU-intensiv
optional_plots = True # Plots in 3) nicht empfohlen für occupancy_grid_width/height > 30 und rotation_step < 30 
gradient_decent_plots = False # Plots in 4) nicht empfohlen für occupancy_grid_width/height > 20 und rotation_step < 90

# Initialisiertes Szenario anzeigen (nicht verändern)
fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=False,
    grid=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Szenario "Skalierung Dimensionen x4": 12x20 Roboter - 30° Rotationsschritte - 80x50 Occu.Grid - Labyrinth mit Engstellen

# Imports (nicht verändern)
# %matplotlib widget
import matplotlib.pyplot as plt
from functions.occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Dimensionen Roboter
robot_width = 12 # Breite in X-Richtung
robot_length = 20 # Länge in Y-Richtung

# Rotationsschritte (Grad)
rotation_step = 30

# Start- und Zielpunkt festlegen: (X,Y,Rotationzustand) => Rotation in Grad = Rotationzustand * 'rotation_step'
start_point = (0, 0, 0)
goal_point = (56, 47, 3)
current_position=start_point # Initialisierung der aktuellen Position

# Potenzialfunktion (disjunkte Auswahl)
wavefront_potential_function = True
attraction_repulsion_potential_function = False
#attraction_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'
#repulsion_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'

# Dimensionen Occupancy Grid
occupancy_grid_width = 80 # Breite des Occupancy Grid in X-Richtung
occupancy_grid_length = 50 # Länge des Occupancy Grid in Y-Richtung
occupancy_grid = generate_empty_occupancy_grid(
    occupancy_grid_width=occupancy_grid_width,
    occupancy_grid_length=occupancy_grid_length
)

# Hindernisse im Occupancy Grid: Aufgespanntes Rechteck von x bis x + 'obstacle_width'  und y bis y + 'obstacle_length'.
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=4,
    obstacle_length=24,
    x=20,
    y=0)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=4,
    obstacle_length=10,
    x=20,
    y=40)    
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=4,
    obstacle_length=30,
    x=48,
    y=16)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=16,
    obstacle_length=4,
    x=48,
    y=20)

# Berechnung der Plots aktivieren bzw. deaktivieren wenn CPU-intensiv
optional_plots = False # Plots in 3) nicht empfohlen für occupancy_grid_width/height > 30 und rotation_step < 30 
gradient_decent_plots = False # Plots in 4) nicht empfohlen für occupancy_grid_width/height > 20 und rotation_step < 90

# Initialisiertes Szenario anzeigen (nicht verändern)
fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=False,
    grid=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Szenario "Skalierung Dimensionen x8": 24x40 Roboter - 5° Rotationsschritte - 160x100 Occu.Grid - Labyrinth mit Engstellen

# Imports (nicht verändern)
# %matplotlib widget
import matplotlib.pyplot as plt
from functions.occupancy_grid import add_obstacle, generate_empty_occupancy_grid, plot_occupancy_grid

# Dimensionen Roboter
robot_width = 24 # Breite in X-Richtung
robot_length = 40 # Länge in Y-Richtung

# Rotationsschritte (Grad)
rotation_step = 5

# Start- und Zielpunkt festlegen: (X,Y,Rotationzustand) => Rotation in Grad = Rotationzustand * 'rotation_step'
start_point = (0, 0, 0)
goal_point = (112, 94, 18)
current_position=start_point # Initialisierung der aktuellen Position

# Potenzialfunktion (disjunkte Auswahl)
wavefront_potential_function = True
attraction_repulsion_potential_function = False
#attraction_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'
#repulsion_weight = ... # Nur relevant für 'attraction_repulsion_potential_function = True'

# Dimensionen Occupancy Grid
occupancy_grid_width = 160 # Breite des Occupancy Grid in X-Richtung
occupancy_grid_length = 100 # Länge des Occupancy Grid in Y-Richtung
occupancy_grid = generate_empty_occupancy_grid(
    occupancy_grid_width=occupancy_grid_width,
    occupancy_grid_length=occupancy_grid_length
)

# Hindernisse im Occupancy Grid: Aufgespanntes Rechteck von x bis x + 'obstacle_width'  und y bis y + 'obstacle_length'.
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=8,
    obstacle_length=48,
    x=40,
    y=0)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=8,
    obstacle_length=20,
    x=40,
    y=80)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=8,
    obstacle_length=60,
    x=96,
    y=32)
occupancy_grid = add_obstacle(
    occupancy_grid=occupancy_grid,
    obstacle_width=32,
    obstacle_length=8,
    x=96,
    y=40)

# Berechnung der Plots aktivieren bzw. deaktivieren wenn CPU-intensiv
optional_plots = False # Plots in 3) nicht empfohlen für occupancy_grid_width/height > 30 und rotation_step < 30 
gradient_decent_plots = False # Plots in 4) nicht empfohlen für occupancy_grid_width/height > 20 und rotation_step < 90

# Initialisiertes Szenario anzeigen (nicht verändern)
fig = plt.figure()
plot_axis = fig.add_subplot(111)
plot_occupancy_grid(
    occupancy_grid=occupancy_grid, 
    goal_point=goal_point, 
    plot_axis=plot_axis, 
    robot_width=robot_width, 
    robot_length=robot_length,
    ticks=False,
    grid=True,
    start_point=start_point,
    rotation_step=rotation_step)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # 2) Berechnungen durchführen

# %%
# Compute Configuration Space
from functions.configuration_space import compute_configuration_space
configuration_space = compute_configuration_space(
    robot_length=robot_length, 
    robot_width=robot_width, 
    rotation_step=rotation_step, 
    occupancy_grid=occupancy_grid)

# Compute potentials
from functions.potential import compute_potential_attraction_repulsion, compute_potential_wavefront
import warnings
if attraction_repulsion_potential_function is not None and attraction_repulsion_potential_function == True:
    if wavefront_potential_function is not None and wavefront_potential_function == True:
        warnings.warn("both 'attraction_repulsion_potential_function' and 'wavefront_potential_function' = True")
    if attraction_weight is None or repulsion_weight is None:
        raise Exception("Please set both the 'attraction_weight' and 'repulsion_weight'")
    print("Potential function: attractive & repulsive potential")
    attractive_potential, repulsive_potential = compute_potential_attraction_repulsion(
        configuration_space=configuration_space,
        goal=goal_point,
        attraction_weight=attraction_weight, 
        repulsion_weight=repulsion_weight
    )
    potential = attractive_potential + repulsive_potential
    potential[goal_point[2],goal_point[1],goal_point[0]] = 0
elif wavefront_potential_function is not None and wavefront_potential_function == True:
    if attraction_repulsion_potential_function is not None and attraction_repulsion_potential_function == True:
        warnings.warn("both 'attraction_repulsion_potential_function' and 'wavefront_potential_function' = True")
    print("Potential function: wavefront potential")
    potential_0, potential_650, potential_1250, potential = compute_potential_wavefront(
        configuration_space=configuration_space,
        goal=goal_point
    )
else:
    raise Exception("Please choose exactly one potential function by setting either 'wavefront_potential_function' or 'attraction_repulsion_potential_function' = True")

# Compute Gradients
from functions.gradients import compute_gradients, compute_obstacle_gradients, fix_local_maxima
force_field_x, force_field_y, force_field_rotation = compute_gradients(potential, goal_point)
compute_obstacle_gradients(force_field_x, force_field_y, force_field_rotation, potential)
fix_local_maxima(force_field_x, force_field_y, force_field_rotation, potential, goal_point)

# %% [markdown]
# # 3) Plots ausgeben (optional)

# %%
if not optional_plots:
    raise Exception("For this scenario, plots will be very CPU intensive. Comment out this line to proceed nevertheless. ")


# Plot Expanded Occupancy Grids
from functions.occupancy_grid import plot_occupancy_grid
import numpy as np
rotations = np.arange(0, 360, rotation_step)
fig = plt.figure(figsize=(13, len(rotations)))
fig.suptitle('Expanded Occupancy Grids')
for index, rotation in enumerate(rotations):      
    ax_occupancy_grid = fig.add_subplot(int(np.ceil(len(rotations)/4)), 4, index+1)
    plot_occupancy_grid(
        occupancy_grid=configuration_space[index], 
        goal_point=goal_point, 
        plot_axis=ax_occupancy_grid, 
        start_point=start_point,
        plot_title="Expanded Occupancy Grid\n" + str(rotation) + "° Rotation",
        ticks=False,
        rotation_step = rotation_step,
        grid=False)
plt.show()


# Plot 3D Configuration Space
import numpy as np
import matplotlib.pyplot as plt
from functions.configuration_space import plot_configuration_space
fig = plt.figure(figsize=(13, 8))
fig.suptitle('3D Configuration Space')
plot_axis = fig.add_subplot(111, projection='3d')
plot_configuration_space(
    configuration_space=configuration_space, 
    goal_point=goal_point,
    start_point=start_point,
    rotation_step=rotation_step,
    ax=plot_axis)
plt.show()


# Plot Potential
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from functions.potential import plot_potential_stacked, plot_potential_slice
rotations = np.arange(0, 360, rotation_step)
fig = plt.figure(figsize=(13, 4 + len(rotations)))
fig.suptitle('Potential (Stacked and per Rotation Layer)')
ax_potential_stacked = fig.add_subplot(1 + int(np.ceil(len(rotations)/4)), 4, (2,3), projection='3d')
plot_potential_stacked(potential, 'Potential (all Rotations)', ax_potential_stacked, rotation_step, 0.8)
for index, rotation in enumerate(rotations):  
    ax_potential_slice = fig.add_subplot(1 + int(np.ceil(len(rotations)/4)), 4, 5 + index, projection='3d')
    plot_potential_slice(potential[index], 'Potential for ' + str(rotation) + '° Rotation', ax_potential_slice, 0.8)
plt.subplots_adjust(wspace=0.3,hspace=0)
plt.show()


# Plot Gradients ("Force Field")
from functions.configuration_space import plot_configuration_space
fig = plt.figure(figsize=(13, 8))
fig.suptitle('Force Field (Gradients)')
plot_axis = fig.add_subplot(111, projection='3d')
plot_configuration_space(
    configuration_space=configuration_space, 
    force_field_x=force_field_x, 
    force_field_y=force_field_y, 
    force_field_rotation=force_field_rotation, 
    goal_point=goal_point, 
    start_point=start_point,
    ax=plot_axis,
    rotation_step=rotation_step)
plt.show()

# %% [markdown]
# # 4) Gradientenabstieg initialisieren

# %%
from functions.gradients import gradient_descent_step, update_gradient_descent_plots
import numpy as np
from time import sleep

if gradient_decent_plots:
    rotations = np.arange(0, 360, rotation_step)
else:
    rotations = []

fig = plt.figure(figsize=(13, 5 + len(rotations)))

if gradient_decent_plots:
    ax_cs_2D = []
    for index, rotation in enumerate(rotations):      
        ax_cs_2D.append(fig.add_subplot(1 + int(np.ceil(len(rotations)/4)), 4, 4 + index+1))
    ax_cs_3D = fig.add_subplot(1 + int(np.ceil(len(rotations)/4)), 4, (3,4), projection='3d')
else:
    ax_cs_2D = []    
    ax_cs_3D = None

path = []

ax_occupancy_grid = fig.add_subplot(1 + int(np.ceil(len(rotations)/4)), 4, (1,2))

update_gradient_descent_plots(
        occupancy_grid=occupancy_grid,
        configuration_space=configuration_space,
        start_point=start_point,
        goal_point=goal_point,
        current_position=current_position,
        robot_width=robot_width,
        robot_length=robot_length,
        rotation_step=rotation_step,
        ax_occupancy_grid=ax_occupancy_grid,
        ax_cs_2D=ax_cs_2D,
        ax_cs_3D=ax_cs_3D,
        force_field_x=force_field_x,
        force_field_y=force_field_y,
        force_field_rotation=force_field_rotation,
        gradient_decent_plots=gradient_decent_plots,
        path=path,
        ticks=False,
        grid=False)

fig.suptitle('Please execute cell below')
plt.subplots_adjust(wspace=0.3,hspace=0)

fig.canvas.draw()

# %% [markdown]
# # 5) Gradientenabstieg starten - Plot von 4) beobachten

# %%
fig.suptitle("Descending Gradients ...")

try:
    while True:
        current_position = gradient_descent_step(
                            current_position=current_position,
                            force_field_x=force_field_x,
                            force_field_y=force_field_y,
                            force_field_rotation=force_field_rotation,
                            path=path,
                            goal_point=goal_point)  

        update_gradient_descent_plots(
            occupancy_grid=occupancy_grid,
            configuration_space=configuration_space,
            start_point=start_point,
            goal_point=goal_point,
            current_position=current_position,
            robot_width=robot_width,
            robot_length=robot_length,
            rotation_step=rotation_step,
            ax_occupancy_grid=ax_occupancy_grid,
            ax_cs_2D=ax_cs_2D,
            ax_cs_3D=ax_cs_3D,
            force_field_x=force_field_x,
            force_field_y=force_field_y,
            force_field_rotation=force_field_rotation,
            gradient_decent_plots=gradient_decent_plots,
            path=path,
            ticks=False,
            grid=False)
        
        sleep(0.05)
        fig.canvas.draw()
except Exception as e:
    fig.suptitle(e)
